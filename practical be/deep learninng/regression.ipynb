# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
df = pd.read_csv(r"C:\Users\ASUS\Desktop\practical be\dataset\boston_housing.csv")
X = df.loc[:, df.columns != 'MEDV']
y = df.loc[:, df.columns == 'MEDV']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=123)
df
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %%
mms = MinMaxScaler()
mms.fit(X_train)
X_train = mms.transform(X_train)
X_test = mms.transform(X_test)

# %%
model = Sequential()
model.add(Dense(256, input_shape=(13, ), activation='relu', name='dense_1'))
model.add(Dense(128, activation='relu', name='dense_2'))
model.add(Dense(64, activation='relu', name='dense_3'))
model.add(Dense(1, activation='linear', name='dense_output'))
model.compile(optimizer='adam', loss='mse', metrics=['mse'])
model.summary()
# Out:
# C:\Users\ASUS\anaconda3\envs\practical\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_1 (Dense)                 │ (None, 256)            │         3,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_output (Dense)            │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 44,801 (175.00 KB)
#  Trainable params: 44,801 (175.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(X_train, y_train, epochs=100, validation_split=0.05, verbose = 1)
# Out:
# Epoch 1/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 580.4441 - mse: 580.4441 - val_loss: 526.0808 - val_mse: 526.0808
# Epoch 2/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 445.5308 - mse: 445.5308 - val_loss: 289.4720 - val_mse: 289.4720
# Epoch 3/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 211.0029 - mse: 211.0029 - val_loss: 131.1754 - val_mse: 131.1754
# Epoch 4/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 138.2385 - mse: 138.2385 - val_loss: 105.4627 - val_mse: 105.4627
# Epoch 5/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 92.5468 - mse: 92.5468 - val_loss: 94.4812 - val_mse: 94.4812
# Epoch 6/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 72.1869 - mse: 72.1869 - val_loss: 76.4125 - val_mse: 76.4125
# Epoch 7/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 58.7574 - mse: 58.7574 - val_loss: 70.4199 - val_mse: 70.4199
# Epoch 8/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 51.5534 - mse: 51.5534 - val_loss: 65.3213 - val_mse: 65.3213
# Epoch 9/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 47.2883 - mse: 47.2883 - val_loss: 61.3168 - val_mse: 61.3168
# Epoch 10/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 44.0850 - mse: 44.0850 - val_loss: 57.8632 - val_mse: 57.8632
# Epoch 11/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 40.8501 - mse: 40.8501 - val_loss: 53.8989 - val_mse: 53.8989
# Epoch 12/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 37.7414 - mse: 37.7414 - val_loss: 50.4356 - val_mse: 50.4356
# Epoch 13/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 34.6995 - mse: 34.6995 - val_loss: 46.8101 - val_mse: 46.8101
# Epoch 14/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 31.8377 - mse: 31.8377 - val_loss: 43.3666 - val_mse: 43.3666
# Epoch 15/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 29.1719 - mse: 29.1719 - val_loss: 40.0667 - val_mse: 40.0667
# Epoch 16/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 26.8319 - mse: 26.8319 - val_loss: 37.2549 - val_mse: 37.2549
# Epoch 17/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 24.8387 - mse: 24.8387 - val_loss: 34.9807 - val_mse: 34.9807
# Epoch 18/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 23.2085 - mse: 23.2085 - val_loss: 33.1396 - val_mse: 33.1396
# Epoch 19/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 21.8972 - mse: 21.8972 - val_loss: 31.7988 - val_mse: 31.7988
# Epoch 20/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 20.9002 - mse: 20.9002 - val_loss: 30.8513 - val_mse: 30.8513
# Epoch 21/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 20.1226 - mse: 20.1226 - val_loss: 30.0318 - val_mse: 30.0318
# Epoch 22/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 19.5093 - mse: 19.5093 - val_loss: 29.4838 - val_mse: 29.4838
# Epoch 23/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 19.0065 - mse: 19.0065 - val_loss: 28.9242 - val_mse: 28.9242
# Epoch 24/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 18.5650 - mse: 18.5650 - val_loss: 28.4434 - val_mse: 28.4434
# Epoch 25/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 18.1614 - mse: 18.1614 - val_loss: 27.9207 - val_mse: 27.9207
# Epoch 26/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 17.7875 - mse: 17.7875 - val_loss: 27.4148 - val_mse: 27.4148
# Epoch 27/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 17.4643 - mse: 17.4643 - val_loss: 27.0579 - val_mse: 27.0579
# Epoch 28/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 17.1780 - mse: 17.1780 - val_loss: 26.7046 - val_mse: 26.7046
# Epoch 29/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 16.9229 - mse: 16.9229 - val_loss: 26.2368 - val_mse: 26.2368
# Epoch 30/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 16.6714 - mse: 16.6714 - val_loss: 25.6695 - val_mse: 25.6695
# Epoch 31/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 16.4158 - mse: 16.4158 - val_loss: 25.3267 - val_mse: 25.3267
# Epoch 32/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 16.1938 - mse: 16.1938 - val_loss: 25.0635 - val_mse: 25.0635
# Epoch 33/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 15.9665 - mse: 15.9665 - val_loss: 24.8939 - val_mse: 24.8939
# Epoch 34/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 15.7633 - mse: 15.7633 - val_loss: 24.2609 - val_mse: 24.2609
# Epoch 35/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 15.5056 - mse: 15.5056 - val_loss: 23.8591 - val_mse: 23.8591
# Epoch 36/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 15.2672 - mse: 15.2672 - val_loss: 23.6850 - val_mse: 23.6850
# Epoch 37/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 15.1072 - mse: 15.1072 - val_loss: 23.4146 - val_mse: 23.4146
# Epoch 38/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 14.9098 - mse: 14.9098 - val_loss: 23.1401 - val_mse: 23.1401
# Epoch 39/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 14.7366 - mse: 14.7366 - val_loss: 22.7112 - val_mse: 22.7112
# Epoch 40/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 14.5208 - mse: 14.5208 - val_loss: 22.2743 - val_mse: 22.2743
# Epoch 41/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 14.3077 - mse: 14.3077 - val_loss: 21.9425 - val_mse: 21.9425
# Epoch 42/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 14.1228 - mse: 14.1228 - val_loss: 21.5879 - val_mse: 21.5879
# Epoch 43/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 13.9422 - mse: 13.9422 - val_loss: 21.2272 - val_mse: 21.2272
# Epoch 44/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 13.7660 - mse: 13.7660 - val_loss: 20.8567 - val_mse: 20.8567
# Epoch 45/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 13.5725 - mse: 13.5725 - val_loss: 20.4437 - val_mse: 20.4437
# Epoch 46/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 13.3902 - mse: 13.3902 - val_loss: 20.0839 - val_mse: 20.0839
# Epoch 47/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 13.2015 - mse: 13.2015 - val_loss: 19.7280 - val_mse: 19.7280
# Epoch 48/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 13.0347 - mse: 13.0347 - val_loss: 19.3028 - val_mse: 19.3028
# Epoch 49/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 12.8680 - mse: 12.8680 - val_loss: 18.9263 - val_mse: 18.9263
# Epoch 50/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 12.7078 - mse: 12.7078 - val_loss: 18.5541 - val_mse: 18.5541
# Epoch 51/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 12.5577 - mse: 12.5577 - val_loss: 18.1390 - val_mse: 18.1390
# Epoch 52/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 12.3734 - mse: 12.3734 - val_loss: 17.7740 - val_mse: 17.7740
# Epoch 53/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 12.2342 - mse: 12.2342 - val_loss: 17.3103 - val_mse: 17.3103
# Epoch 54/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 12.0474 - mse: 12.0474 - val_loss: 16.8887 - val_mse: 16.8887
# Epoch 55/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 11.9066 - mse: 11.9066 - val_loss: 16.3946 - val_mse: 16.3946
# Epoch 56/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 11.7265 - mse: 11.7265 - val_loss: 15.9865 - val_mse: 15.9865
# Epoch 57/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 11.5598 - mse: 11.5598 - val_loss: 15.5148 - val_mse: 15.5148
# Epoch 58/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 11.3995 - mse: 11.3995 - val_loss: 15.1224 - val_mse: 15.1224
# Epoch 59/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 11.2742 - mse: 11.2742 - val_loss: 14.7729 - val_mse: 14.7729
# Epoch 60/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 11.1420 - mse: 11.1420 - val_loss: 14.3160 - val_mse: 14.3160
# Epoch 61/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 10.9569 - mse: 10.9569 - val_loss: 13.9293 - val_mse: 13.9293
# Epoch 62/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 10.8183 - mse: 10.8183 - val_loss: 13.5266 - val_mse: 13.5266
# Epoch 63/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 10.6757 - mse: 10.6757 - val_loss: 13.1606 - val_mse: 13.1606
# Epoch 64/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 10.5422 - mse: 10.5422 - val_loss: 12.7617 - val_mse: 12.7617
# Epoch 65/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 10.3677 - mse: 10.3677 - val_loss: 12.3947 - val_mse: 12.3947
# Epoch 66/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 10.2509 - mse: 10.2509 - val_loss: 12.0861 - val_mse: 12.0861
# Epoch 67/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 10.1068 - mse: 10.1068 - val_loss: 11.7006 - val_mse: 11.7006
# Epoch 68/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.9887 - mse: 9.9887 - val_loss: 11.2266 - val_mse: 11.2266
# Epoch 69/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.8231 - mse: 9.8231 - val_loss: 10.9341 - val_mse: 10.9341
# Epoch 70/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.6914 - mse: 9.6914 - val_loss: 10.6281 - val_mse: 10.6281
# Epoch 71/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.5905 - mse: 9.5905 - val_loss: 10.2778 - val_mse: 10.2778
# Epoch 72/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.4247 - mse: 9.4247 - val_loss: 10.0924 - val_mse: 10.0924
# Epoch 73/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.3560 - mse: 9.3560 - val_loss: 9.8382 - val_mse: 9.8382
# Epoch 74/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 9.2415 - mse: 9.2415 - val_loss: 9.4944 - val_mse: 9.4944
# Epoch 75/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.1190 - mse: 9.1190 - val_loss: 9.2155 - val_mse: 9.2155
# Epoch 76/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.0232 - mse: 9.0232 - val_loss: 9.0333 - val_mse: 9.0333
# Epoch 77/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.9273 - mse: 8.9273 - val_loss: 8.8052 - val_mse: 8.8052
# Epoch 78/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.7751 - mse: 8.7751 - val_loss: 8.6260 - val_mse: 8.6260
# Epoch 79/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 8.7406 - mse: 8.7406 - val_loss: 8.4014 - val_mse: 8.4014
# Epoch 80/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.6057 - mse: 8.6057 - val_loss: 8.1982 - val_mse: 8.1982
# Epoch 81/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.5192 - mse: 8.5192 - val_loss: 8.0827 - val_mse: 8.0827
# Epoch 82/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.4524 - mse: 8.4524 - val_loss: 7.8717 - val_mse: 7.8717
# Epoch 83/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.3684 - mse: 8.3684 - val_loss: 7.7065 - val_mse: 7.7065
# Epoch 84/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.2639 - mse: 8.2639 - val_loss: 7.5228 - val_mse: 7.5228
# Epoch 85/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.1822 - mse: 8.1822 - val_loss: 7.2853 - val_mse: 7.2853
# Epoch 86/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.0851 - mse: 8.0851 - val_loss: 7.0715 - val_mse: 7.0715
# Epoch 87/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.9505 - mse: 7.9505 - val_loss: 6.9585 - val_mse: 6.9585
# Epoch 88/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.8372 - mse: 7.8372 - val_loss: 6.8843 - val_mse: 6.8843
# Epoch 89/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.7714 - mse: 7.7714 - val_loss: 6.6268 - val_mse: 6.6268
# Epoch 90/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 7.6842 - mse: 7.6842 - val_loss: 6.4354 - val_mse: 6.4354
# Epoch 91/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.5357 - mse: 7.5357 - val_loss: 6.3545 - val_mse: 6.3545
# Epoch 92/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.5036 - mse: 7.5036 - val_loss: 6.2740 - val_mse: 6.2740
# Epoch 93/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.3873 - mse: 7.3873 - val_loss: 6.1602 - val_mse: 6.1602
# Epoch 94/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 7.3010 - mse: 7.3010 - val_loss: 6.0491 - val_mse: 6.0491
# Epoch 95/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.2176 - mse: 7.2176 - val_loss: 5.8702 - val_mse: 5.8702
# Epoch 96/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.1175 - mse: 7.1175 - val_loss: 5.8282 - val_mse: 5.8282
# Epoch 97/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.0549 - mse: 7.0549 - val_loss: 5.7344 - val_mse: 5.7344
# Epoch 98/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.9631 - mse: 6.9631 - val_loss: 5.6871 - val_mse: 5.6871
# Epoch 99/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6.9317 - mse: 6.9317 - val_loss: 5.6548 - val_mse: 5.6548
# Epoch 100/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.8632 - mse: 6.8632 - val_loss: 5.6040 - val_mse: 5.6040

# %%
pd.DataFrame(history.history).plot(figsize=(10,7))
plt.title("Metrics graph")
plt.show()

# %%
mse_nn, mae_nn = model.evaluate(X_test, y_test)
print('Mean squared error on test data: ', mse_nn)
print('Mean absolute error on test data: ', mae_nn)

rmse_nn = np.sqrt(mse_nn)
print('Root Mean Squared Error on test data: ', rmse_nn)

r2_nn = r2_score(y_test, model.predict(X_test))
print('R-squared on test data: ', r2_nn)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 24.3221 - mse: 24.3221
# Mean squared error on test data:  16.13458251953125
# Mean absolute error on test data:  16.13458251953125
# Root Mean Squared Error on test data:  4.016787587056509
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# R-squared on test data:  0.8003839254379272

# %%
sns.regplot(x=y_test, y=model.predict(X_test))
plt.title("Regression Line for Predicted values")
plt.show()
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
